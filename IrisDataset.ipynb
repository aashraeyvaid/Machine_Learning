# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris['species'].value_counts()                          #to count number of unique values in column 'species'
# Out:
# species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
iris.plot(kind='scatter',x='sepal_length',y='sepal_width')
plt.grid()
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='species',height=4)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris,col='species',height=4)\
.map(plt.scatter,'sepal_length','sepal_width')\
.add_legend()
plt.show()

# %%
sns.relplot(data=iris,x='sepal_length',y='sepal_width',hue='species',height=4)

# %%
plt.close()

# %%
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',height=3)
plt.show()

# %% [raw]
# We can see in the above plots that we got a matrix of different graphs and the diagonal elements are different from element grahs.
#
# Now, the X and Y axis can be seen by seeing the left most and bottom most fields. Then we see the best plot that will distinguish teh 3 species.
# We get the last plot of second last row to be the best seperator. Now we can create an easy model for it.

# %%
iris_setosa=iris.loc[iris['species']=='Setosa']
iris_virginica=iris.loc[iris['species']=='Virginica']
iris_versicolor=iris.loc[iris['species']=='Versicolor']

plt.plot(iris_setosa['petal_length'],np.zeros_like(iris_setosa['petal_length']))
plt.plot(iris_virginica['petal_length'],np.zeros_like(iris_virginica['petal_length']))
plt.plot(iris_versicolor['petal_length'],np.zeros_like(iris_versicolor['petal_length']))
plt.show()

# %%
iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
iris_virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
iris_versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 53           5.5          2.3           4.0          1.3  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor
# 55           5.7          2.8           4.5          1.3  Versicolor
# 56           6.3          3.3           4.7          1.6  Versicolor
# 57           4.9          2.4           3.3          1.0  Versicolor
# 58           6.6          2.9           4.6          1.3  Versicolor
# 59           5.2          2.7           3.9          1.4  Versicolor
# 60           5.0          2.0           3.5          1.0  Versicolor
# 61           5.9          3.0           4.2          1.5  Versicolor
# 62           6.0          2.2           4.0          1.0  Versicolor
# ...

# %%
sns.FacetGrid(iris,hue='species',height=5)\
   .map(sns.histplot,'petal_length',kde=True)\
   .add_legend();
plt.show()

# %%
sns.FacetGrid(iris,hue='species',height=5)\
   .map(sns.histplot,'sepal_length',kde=True)\
   .add_legend();
plt.show()

# %%
sns.FacetGrid(iris,hue='species',height=5)\
   .map(sns.histplot,'sepal_width',kde=True)\
   .add_legend();
plt.show()

# %%
sns.FacetGrid(iris,hue='species',height=5)\
   .map(sns.histplot,'petal_width',kde=True)\
   .add_legend();
plt.show()

# %%
sns.FacetGrid(iris_setosa,hue='species',height=5)\
   .map(sns.kdeplot,'petal_length')
plt.show()

# %%
count,bin_edges=np.histogram(iris_setosa['petal_length'],bins=10,density=True)

# %%
count
# Out:
# array([0.22222222, 0.22222222, 0.44444444, 1.55555556, 2.88888889,
#        2.88888889, 1.55555556, 0.88888889, 0.        , 0.44444444])

# %%
bin_edges
# Out:
# array([1.  , 1.09, 1.18, 1.27, 1.36, 1.45, 1.54, 1.63, 1.72, 1.81, 1.9 ])

# %%
pdf=count/(sum(count))

# %%
pdf
# Out:
# array([0.02, 0.02, 0.04, 0.14, 0.26, 0.26, 0.14, 0.08, 0.  , 0.04])

# %%
cdf=np.cumsum(pdf)

# %%
cdf
# Out:
# array([0.02, 0.04, 0.08, 0.22, 0.48, 0.74, 0.88, 0.96, 0.96, 1.  ])

# %%
plt.plot(bin_edges[1:],pdf,'b-')
plt.plot(bin_edges[1:],cdf,'y-')
plt.show()

# %%
count1,bin_edge1=np.histogram(iris_virginica['petal_length'],bins=10,density=True)
pdf1=count1/sum(count1)
cdf1=np.cumsum(pdf1)
plt.plot(bin_edge1[1:],pdf1)
plt.plot(bin_edge1[1:],cdf1)
plt.show()

# %%
count2,bin_edge2=np.histogram(iris_versicolor['petal_length'],bins=10,density=True)
pdf2=count2/sum(count2)
cdf2=np.cumsum(pdf2)
plt.plot(bin_edge2[1:],pdf2)
plt.plot(bin_edge2[1:],cdf2)
plt.show()

# %%
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.plot(bin_edge1[1:],pdf1)
plt.plot(bin_edge1[1:],cdf1)
plt.plot(bin_edge2[1:],pdf2)
plt.plot(bin_edge2[1:],cdf2)
plt.show()

# %%
print(np.mean(iris_setosa['petal_length']))
print(np.mean(iris_virginica['petal_length']))
print(np.mean(iris_versicolor['petal_length']))
# Out:
# 1.4620000000000002
# 5.5520000000000005
# 4.26

# %%
print(np.std(iris_setosa['petal_length']))
print(np.std(iris_virginica['petal_length']))
print(np.std(iris_versicolor['petal_length']))
# Out:
# 0.17191858538273283
# 0.546347874526844
# 0.4651881339845203

# %%
print(np.median(iris_setosa['petal_length']))
print(np.median(iris_virginica['petal_length']))
print(np.median(iris_versicolor['petal_length']))
# Out:
# 1.5
# 5.55
# 4.35

# %%
np.percentile(iris_setosa['petal_length'],np.arange(0,100,25))
# Out:
# array([1.   , 1.4  , 1.5  , 1.575])

# %%
np.percentile(iris_virginica['petal_length'],np.arange(0,100,25))
# Out:
# array([4.5  , 5.1  , 5.55 , 5.875])

# %%
np.percentile(iris_versicolor['petal_length'],np.arange(0,100,25))
# Out:
# array([3.  , 4.  , 4.35, 4.6 ])

# %%
from statsmodels import robust
print(robust.mad(iris_setosa['petal_length']))
print(robust.mad(iris_virginica['petal_length']))
print(robust.mad(iris_versicolor['petal_length']))
# Out:
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
sns.jointplot(x='petal_length',y='petal_width',data=iris_setosa,kind='kde',cmap='Blues',fill=True)
plt.show()
